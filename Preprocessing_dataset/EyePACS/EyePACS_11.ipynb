# %%
import cv2
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
from PIL import Image
from functools import reduce
import warnings
def compose(*funcs):
    if funcs:
        return reduce(lambda f, g: lambda *a, **kw: g(f(*a, **kw)), funcs)
    else:
        raise ValueError('Composition of empty sequence not supported.')

def letterbox_image(image_pil, target_size_wh, padding_color):
    """
    Resizes an image to a target size while maintaining aspect ratio by adding padding.
    The input image (image_pil) is expected to be a PIL Image.
    The padding_color is an integer for grayscale images.
    """
    iw, ih = image_pil.size
    w_target, h_target = target_size_wh

    if iw == 0 or ih == 0: # Handle empty input image
        return Image.new('L', target_size_wh, padding_color)

    scale = min(w_target/iw, h_target/ih)
    nw = int(iw*scale)
    nh = int(ih*scale)

    # Ensure new dimensions are at least 1 pixel if scaled down significantly
    nw = max(1, nw)
    nh = max(1, nh)

    resized_image = image_pil.resize((nw,nh), Image.BICUBIC)
    
    new_image = Image.new('L', target_size_wh, padding_color) # 'L' for grayscale
    new_image.paste(resized_image, ((w_target-nw)//2, (h_target-nh)//2))
    return new_image


def convert_to_grayscale(img_bgr):
    if len(img_bgr.shape) == 2: return img_bgr
    if img_bgr.shape[2] == 1: return img_bgr.reshape(img_bgr.shape[0], img_bgr.shape[1])
    # Specific weights for BGR to Grayscale conversion
    b, g, r = cv2.split(img_bgr)
    gray_img = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray_img.astype(np.uint8)

def apply_clahe(img_gray):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    return clahe.apply(img_gray)

def apply_gaussian_blur(img_gray, kernel_size=(5,5)):
    return cv2.GaussianBlur(img_gray, kernel_size, 0)

def apply_median_filter(img_gray, kernel_size=5):
    return cv2.medianBlur(img_gray, kernel_size)

def cv2_to_pil_grayscale(img_cv2):
    return Image.fromarray(img_cv2, mode='L')

def pil_to_cv2_grayscale(img_pil):
    return np.array(img_pil)

def segment_fundus_and_create_mask(image_cv2_gray, image_name_for_debug=""):
    """
    Segmenta il fondo oculare e restituisce una maschera binaria e il bounding box del fondo.
    Restituisce: (mask, bounding_box) dove bounding_box è (x, y, w, h) o None.
    """
    # Parametri di tuning per la segmentazione
    blur_kernel_size_seg = (15, 15) 
    threshold_value = 30 
    morph_kernel_size_open = (15,15) # Kernel per MORPH_OPEN
    morph_kernel_size_close = (35,35) # Kernel più grande per MORPH_CLOSE per unire regioni
    
    blurred_for_seg = cv2.GaussianBlur(image_cv2_gray, blur_kernel_size_seg, 0)
    
    # Prova cv2.THRESH_OTSU se un valore fisso non è robusto
    # _, thresh_img = cv2.threshold(blurred_for_seg, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    _, thresh_img = cv2.threshold(blurred_for_seg, threshold_value, 255, cv2.THRESH_BINARY)

    kernel_open = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, morph_kernel_size_open)
    kernel_close = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, morph_kernel_size_close)
    
    thresh_img = cv2.morphologyEx(thresh_img, cv2.MORPH_OPEN, kernel_open, iterations=1)
    thresh_img = cv2.morphologyEx(thresh_img, cv2.MORPH_CLOSE, kernel_close, iterations=2)

    contours, _ = cv2.findContours(thresh_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    mask = np.zeros_like(image_cv2_gray)
    bounding_box = None

    if contours:
        contours = sorted(contours, key=cv2.contourArea, reverse=True)
        # Considera di filtrare contorni troppo piccoli rispetto all'area dell'immagine
        # min_area_ratio = 0.05 # Esempio: il contorno deve essere almeno il 5% dell'immagine
        # if cv2.contourArea(contours[0]) > image_cv2_gray.shape[0] * image_cv2_gray.shape[1] * min_area_ratio:
        fundus_contour = contours[0]
        hull = cv2.convexHull(fundus_contour)
        cv2.drawContours(mask, [hull], -1, (255), thickness=cv2.FILLED)
        bounding_box = cv2.boundingRect(hull) # Restituisce (x, y, w, h)
        # else:
        #    print(f"Attenzione: Contorno principale troppo piccolo per {image_name_for_debug}. L'immagine risultante potrebbe essere nera.")
    else:
        #print(f"Attenzione: Nessun contorno del fondo trovato per {image_name_for_debug}. L'immagine risultante potrebbe essere nera.")
        pass
    return mask, bounding_box

# --- Parametri Globali ---
FINAL_IMAGE_SIZE = (512, 512)
FUNDUS_TARGET_SCALE_FACTOR = 0.9 # Il fondo occuperà il 90% della dimensione maggiore dell'immagine finale
DEBUG_SAVE_INTERMEDIATE = False # Imposta a True per salvare immagini di debug
DEBUG_OUTPUT_DIR = '/home/jupyter-sdm/GENITO/LAVORO_COMPLETO/Dataset_resize/1_IDRiD_DEBUG/'
if DEBUG_SAVE_INTERMEDIATE:
    os.makedirs(DEBUG_OUTPUT_DIR, exist_ok=True)

# %%
warnings.filterwarnings("ignore", "Premature end of JPEG file")

# Percorsi file e cartelle
csv_path = '/home/jupyter-sdm/GENITO/DATASETS/EyePACS/retinopathy_solution.csv'  
image_dir = '/home/jupyter-sdm/GENITO/DATASETS/EyePACS/test6' 
final_output_dir = '/home/jupyter-sdm/GENITO/LAVORO_COMPLETO/Dataset_resize/7_EyePACS'

file_extension = ".jpeg"
column_class_name = 'level'
colum_image_name = 'image'

try:
    df = pd.read_csv(csv_path)
except FileNotFoundError:
    print(f"Errore: File CSV non trovato a {csv_path}")
    exit()

classes = df[column_class_name].unique()
for cls in classes:
    class_output_path = os.path.join(final_output_dir, str(cls))
    os.makedirs(class_output_path, exist_ok=True)

conta_errate = 0
conta_bbox_nulle = 0

for _, row in tqdm(df.iterrows(), total=df.shape[0], desc="Processing", ncols=100, ascii=True):
    image_name_no_ext = row[colum_image_name]
    image_name = image_name_no_ext + file_extension # Verrà aggiornato se si trova .jpeg
    image_class = str(row[column_class_name])
    src_path = os.path.join(image_dir, image_name_no_ext + file_extension) # Prova prima .jpg
    output_class_path = os.path.join(final_output_dir, image_class)

    if not os.path.exists(src_path):
        src_path_jpeg = os.path.join(image_dir, image_name_no_ext + ".jpeg")
        if os.path.exists(src_path_jpeg):
            src_path = src_path_jpeg
            image_name = image_name_no_ext + ".jpeg" # Aggiorna il nome file per l'output
        else:
            conta_errate += 1
            continue
        
    img_bgr = cv2.imread(src_path, cv2.IMREAD_COLOR)
    
    if img_bgr is None:
        conta_errate += 1
        continue
    
    try:
        # 1. Converti in Scala di Grigi
        img_cv2_gray = convert_to_grayscale(img_bgr)

        # 2. Segmenta il fondo, crea la maschera e ottieni il bounding box
        fundus_mask, fundus_bbox = segment_fundus_and_create_mask(img_cv2_gray.copy(), image_name)

        if DEBUG_SAVE_INTERMEDIATE:
            cv2.imwrite(os.path.join(DEBUG_OUTPUT_DIR, f"{image_name_no_ext}_0_gray.png"), img_cv2_gray)
            cv2.imwrite(os.path.join(DEBUG_OUTPUT_DIR, f"{image_name_no_ext}_1_mask.png"), fundus_mask)

        # 3. Applica CLAHE, Gaussian Blur, Median Filter all'immagine in scala di grigi
        img_clahe = apply_clahe(img_cv2_gray)
        img_gaussian_blurred = apply_gaussian_blur(img_clahe)
        img_median_filtered = apply_median_filter(img_gaussian_blurred)
        fully_processed_gray_data = img_median_filtered

        if DEBUG_SAVE_INTERMEDIATE:
             cv2.imwrite(os.path.join(DEBUG_OUTPUT_DIR, f"{image_name_no_ext}_2_fully_processed_gray.png"), fully_processed_gray_data)

        # 4. Applica la maschera per annerire lo sfondo dell'immagine processata
        masked_processed_fundus_cv2 = cv2.bitwise_and(fully_processed_gray_data, fully_processed_gray_data, mask=fundus_mask)

        if DEBUG_SAVE_INTERMEDIATE:
            cv2.imwrite(os.path.join(DEBUG_OUTPUT_DIR, f"{image_name_no_ext}_3_masked_fundus.png"), masked_processed_fundus_cv2)

        # --- Normalizzazione della Dimensione del Fondo ---
        if fundus_bbox:
            x, y, w_bbox, h_bbox = fundus_bbox
            if w_bbox > 0 and h_bbox > 0:
                # Ritaglia il fondo mascherato usando il bounding box
                cropped_fundus_cv2 = masked_processed_fundus_cv2[y:y+h_bbox, x:x+w_bbox]

                if DEBUG_SAVE_INTERMEDIATE:
                    cv2.imwrite(os.path.join(DEBUG_OUTPUT_DIR, f"{image_name_no_ext}_4_cropped_fundus.png"), cropped_fundus_cv2)

                # Calcola le nuove dimensioni per il fondo ritagliato
                target_max_dim_px = int(max(FINAL_IMAGE_SIZE) * FUNDUS_TARGET_SCALE_FACTOR)
                
                current_max_dim_bbox = max(w_bbox, h_bbox)
                scale_ratio = target_max_dim_px / current_max_dim_bbox if current_max_dim_bbox > 0 else 1
                
                new_w = int(w_bbox * scale_ratio)
                new_h = int(h_bbox * scale_ratio)
                
                # Assicura che le nuove dimensioni siano almeno 1x1
                new_w = max(1, new_w)
                new_h = max(1, new_h)

                interpolation = cv2.INTER_AREA if scale_ratio < 1 else cv2.INTER_CUBIC
                resized_cropped_fundus_cv2 = cv2.resize(cropped_fundus_cv2, (new_w, new_h), interpolation=interpolation)
                
                # Converti il fondo normalizzato e ridimensionato in PIL
                image_to_letterbox_pil = cv2_to_pil_grayscale(resized_cropped_fundus_cv2)

                if DEBUG_SAVE_INTERMEDIATE:
                    image_to_letterbox_pil.save(os.path.join(DEBUG_OUTPUT_DIR, f"{image_name_no_ext}_5_resized_cropped_fundus.png"))
            else:
                # Bounding box non valido (es. w o h = 0)
                image_to_letterbox_pil = Image.new('L', (1,1), 0) # Immagine placeholder piccola da letterboxare
                conta_bbox_nulle +=1
        else:
            # Nessun bounding box trovato (nessun contorno)
            image_to_letterbox_pil = Image.new('L', (1,1), 0) # Immagine placeholder
            conta_bbox_nulle +=1
            
        # 5. Letterbox: inserisce l'immagine (ora il fondo normalizzato) in un canvas 512x512
        #    Il colore di padding è 0 (nero) perché lo sfondo del fondo è già nero.
        letterboxed_img_pil = letterbox_image(image_to_letterbox_pil, FINAL_IMAGE_SIZE, padding_color=0) 
        
        # 6. Converti di nuovo in NumPy array (CV2) per il salvataggio
        final_img_to_save = pil_to_cv2_grayscale(letterboxed_img_pil)
        
        # 7. Salva l'immagine elaborata
        output_filename = os.path.splitext(image_name)[0] + '.png'
        output_path = os.path.join(output_class_path, output_filename)
        cv2.imwrite(output_path, final_img_to_save)
        
    except Exception as e:
        import traceback
        conta_errate += 1
        continue

print(f"Numero di immagini non lette o con errori di processing: {conta_errate}")
print(f"Numero di immagini con bounding box del fondo nullo o non valido: {conta_bbox_nulle}")
print("Processo di suddivisione e preprocessing completato!")
# Out:
# Processing:  10%|####1                                      | 5116/53576 [17:22<22:51:27,  1.70s/it]Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Premature end of JPEG file
# Processing:  10%|####1                                      | 5125/53576 [17:40<24:20:07,  1.81s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5126/53576 [17:41<24:02:17,  1.79s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5133/53576 [17:50<21:03:52,  1.57s/it]Premature end of JPEG file
# Premature end of JPEG file
# Processing:  10%|####1                                      | 5138/53576 [18:00<22:49:44,  1.70s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5139/53576 [18:02<22:55:31,  1.70s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5143/53576 [18:10<24:07:23,  1.79s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5151/53576 [18:24<23:46:49,  1.77s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5152/53576 [18:27<25:43:56,  1.91s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5153/53576 [18:30<28:00:42,  2.08s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5156/53576 [18:38<33:25:05,  2.48s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5157/53576 [18:40<29:45:28,  2.21s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5163/53576 [18:47<21:19:51,  1.59s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5176/53576 [19:02<12:23:45,  1.08it/s]Premature end of JPEG file
# Processing:  10%|####1                                      | 5177/53576 [19:03<15:55:50,  1.18s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5182/53576 [19:10<16:16:54,  1.21s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5186/53576 [19:19<24:03:16,  1.79s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5187/53576 [19:22<27:57:26,  2.08s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5188/53576 [19:24<29:29:36,  2.19s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5190/53576 [19:28<25:45:52,  1.92s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5191/53576 [19:29<24:53:11,  1.85s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5192/53576 [19:31<24:49:13,  1.85s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5193/53576 [19:34<27:46:54,  2.07s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5194/53576 [19:37<30:43:43,  2.29s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5196/53576 [19:40<26:43:28,  1.99s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5197/53576 [19:41<24:16:53,  1.81s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5199/53576 [19:45<23:47:00,  1.77s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5200/53576 [19:47<23:59:20,  1.79s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5201/53576 [19:49<28:20:29,  2.11s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5203/53576 [19:54<28:16:52,  2.10s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5205/53576 [19:58<28:45:07,  2.14s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5211/53576 [20:06<15:48:59,  1.18s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5214/53576 [20:10<17:57:29,  1.34s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5216/53576 [20:16<26:21:39,  1.96s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5217/53576 [20:18<26:23:52,  1.97s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5218/53576 [20:19<25:58:31,  1.93s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5219/53576 [20:21<24:25:42,  1.82s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5220/53576 [20:22<22:55:36,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5221/53576 [20:24<23:24:04,  1.74s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5223/53576 [20:28<23:47:08,  1.77s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5227/53576 [20:37<29:09:58,  2.17s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5228/53576 [20:39<27:45:04,  2.07s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5229/53576 [20:40<25:21:43,  1.89s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5230/53576 [20:42<23:39:09,  1.76s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5232/53576 [20:46<24:02:41,  1.79s/it]Premature end of JPEG file
# Processing:  10%|####1                                      | 5233/53576 [20:47<22:56:58,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5234/53576 [20:49<22:05:50,  1.65s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5235/53576 [20:50<22:42:44,  1.69s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5238/53576 [20:53<14:01:06,  1.04s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5242/53576 [20:59<17:02:38,  1.27s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5243/53576 [21:02<23:22:20,  1.74s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5246/53576 [21:07<19:58:06,  1.49s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5248/53576 [21:10<19:55:26,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5249/53576 [21:11<19:48:36,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5250/53576 [21:13<19:44:33,  1.47s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5251/53576 [21:14<20:58:40,  1.56s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5252/53576 [21:16<21:55:05,  1.63s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5254/53576 [21:22<29:34:49,  2.20s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5255/53576 [21:24<31:25:54,  2.34s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5258/53576 [21:29<21:57:24,  1.64s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5260/53576 [21:34<29:12:35,  2.18s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5261/53576 [21:36<27:40:28,  2.06s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5262/53576 [21:38<26:36:11,  1.98s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5263/53576 [21:40<29:17:19,  2.18s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5268/53576 [21:47<16:40:11,  1.24s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5270/53576 [21:52<26:35:18,  1.98s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5271/53576 [21:54<25:59:31,  1.94s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5276/53576 [21:59<15:21:25,  1.14s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5277/53576 [22:01<17:56:54,  1.34s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5282/53576 [22:08<19:56:59,  1.49s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5283/53576 [22:10<19:54:33,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5284/53576 [22:11<19:51:07,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5286/53576 [22:15<22:02:21,  1.64s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5287/53576 [22:17<22:47:39,  1.70s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5288/53576 [22:18<23:17:17,  1.74s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5289/53576 [22:20<23:37:40,  1.76s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5294/53576 [22:26<14:54:14,  1.11s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5295/53576 [22:27<17:41:40,  1.32s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5297/53576 [22:32<24:34:04,  1.83s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5298/53576 [22:35<28:18:23,  2.11s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5306/53576 [22:44<13:12:12,  1.02it/s]Premature end of JPEG file
# Processing:  10%|####2                                      | 5307/53576 [22:46<16:26:15,  1.23s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5308/53576 [22:48<18:44:20,  1.40s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5309/53576 [22:49<19:01:59,  1.42s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5314/53576 [22:58<27:31:46,  2.05s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5322/53576 [23:14<29:56:57,  2.23s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5323/53576 [23:16<31:43:56,  2.37s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5324/53576 [23:19<33:16:53,  2.48s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5325/53576 [23:21<29:14:27,  2.18s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5326/53576 [23:22<26:20:58,  1.97s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5327/53576 [23:24<24:22:43,  1.82s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5328/53576 [23:25<23:00:28,  1.72s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5329/53576 [23:27<23:20:43,  1.74s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5334/53576 [23:32<14:54:08,  1.11s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5336/53576 [23:35<17:24:25,  1.30s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5337/53576 [23:37<19:33:54,  1.46s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5342/53576 [23:44<20:04:56,  1.50s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5343/53576 [23:46<21:20:34,  1.59s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5346/53576 [23:50<17:19:39,  1.29s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5347/53576 [23:52<23:12:18,  1.73s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5350/53576 [23:57<19:37:31,  1.47s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5352/53576 [24:02<27:55:27,  2.08s/it]Premature end of JPEG file
# Processing:  10%|####2                                      | 5353/53576 [24:04<25:30:52,  1.90s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5358/53576 [24:13<28:42:31,  2.14s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5359/53576 [24:15<26:49:30,  2.00s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5362/53576 [24:18<18:58:58,  1.42s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5364/53576 [24:24<27:48:47,  2.08s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5365/53576 [24:26<28:14:44,  2.11s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5368/53576 [24:30<19:50:40,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5369/53576 [24:31<19:49:11,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5373/53576 [24:39<24:02:45,  1.80s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5378/53576 [24:45<17:53:03,  1.34s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5379/53576 [24:46<18:24:35,  1.38s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5382/53576 [24:50<15:18:21,  1.14s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5383/53576 [24:51<16:41:11,  1.25s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5386/53576 [24:54<14:34:27,  1.09s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5387/53576 [24:56<16:07:54,  1.21s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5388/53576 [24:57<17:13:35,  1.29s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5389/53576 [25:00<22:38:12,  1.69s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5394/53576 [25:06<15:14:59,  1.14s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5395/53576 [25:09<22:02:09,  1.65s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5402/53576 [25:18<15:06:51,  1.13s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5403/53576 [25:20<16:26:28,  1.23s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5404/53576 [25:21<17:25:52,  1.30s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5405/53576 [25:23<19:31:34,  1.46s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5407/53576 [25:26<20:31:08,  1.53s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5412/53576 [25:32<14:25:11,  1.08s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5413/53576 [25:33<17:15:49,  1.29s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5416/53576 [25:38<19:14:08,  1.44s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5417/53576 [25:40<20:46:50,  1.55s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5419/53576 [25:43<21:15:49,  1.59s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5422/53576 [25:48<19:50:53,  1.48s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5423/53576 [25:50<24:44:47,  1.85s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5426/53576 [25:55<20:28:11,  1.53s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5427/53576 [25:57<21:32:26,  1.61s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5428/53576 [25:59<22:19:01,  1.67s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5429/53576 [26:01<26:17:35,  1.97s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5432/53576 [26:08<26:38:36,  1.99s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5433/53576 [26:10<29:16:19,  2.19s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5435/53576 [26:15<28:54:40,  2.16s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5436/53576 [26:16<27:23:21,  2.05s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5437/53576 [26:19<30:26:01,  2.28s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5438/53576 [26:22<32:27:19,  2.43s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5439/53576 [26:25<34:01:46,  2.54s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5442/53576 [26:29<23:29:39,  1.76s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5443/53576 [26:32<26:49:23,  2.01s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5444/53576 [26:35<29:41:23,  2.22s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5445/53576 [26:36<27:20:00,  2.04s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5446/53576 [26:38<26:11:42,  1.96s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5447/53576 [26:40<25:22:48,  1.90s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5450/53576 [26:43<17:54:51,  1.34s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5451/53576 [26:45<19:30:36,  1.46s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5453/53576 [26:49<22:12:41,  1.66s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5454/53576 [26:51<22:31:25,  1.69s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5455/53576 [26:52<21:36:18,  1.62s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5456/53576 [26:54<20:49:32,  1.56s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5457/53576 [26:56<25:31:31,  1.91s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5459/53576 [27:01<28:03:08,  2.10s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5460/53576 [27:03<26:39:21,  1.99s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5461/53576 [27:05<29:38:32,  2.22s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5463/53576 [27:10<29:02:52,  2.17s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5468/53576 [27:18<20:34:28,  1.54s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5469/53576 [27:20<21:23:39,  1.60s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5470/53576 [27:21<22:04:52,  1.65s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5472/53576 [27:25<22:47:16,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5480/53576 [27:36<16:15:48,  1.22s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5481/53576 [27:39<22:24:33,  1.68s/it]Premature end of JPEG file
# Processing:  10%|####3                                      | 5482/53576 [27:42<26:45:09,  2.00s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5483/53576 [27:44<25:43:01,  1.93s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5484/53576 [27:45<25:01:11,  1.87s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5485/53576 [27:47<23:11:14,  1.74s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5486/53576 [27:48<21:59:30,  1.65s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5487/53576 [27:50<22:20:33,  1.67s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5489/53576 [27:54<22:54:39,  1.72s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5490/53576 [27:55<22:59:08,  1.72s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5491/53576 [27:57<22:52:21,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5492/53576 [27:59<22:52:16,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5493/53576 [28:00<23:08:26,  1.73s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5495/53576 [28:05<26:46:44,  2.01s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5496/53576 [28:07<29:21:50,  2.20s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5497/53576 [28:10<30:48:05,  2.31s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5498/53576 [28:13<31:49:11,  2.38s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5502/53576 [28:20<22:14:27,  1.67s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5503/53576 [28:21<22:29:00,  1.68s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5506/53576 [28:25<16:48:22,  1.26s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5509/53576 [28:30<20:36:06,  1.54s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5512/53576 [28:36<24:22:36,  1.83s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5516/53576 [28:43<24:40:38,  1.85s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5517/53576 [28:46<27:35:17,  2.07s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5520/53576 [28:50<20:30:11,  1.54s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5521/53576 [28:52<20:04:52,  1.50s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5524/53576 [28:55<16:02:59,  1.20s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5525/53576 [28:57<19:34:32,  1.47s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5526/53576 [28:59<22:08:57,  1.66s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5527/53576 [29:00<21:10:48,  1.59s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5532/53576 [29:05<13:48:26,  1.03s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5533/53576 [29:07<15:23:12,  1.15s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5536/53576 [29:14<27:17:45,  2.05s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5538/53576 [29:17<25:16:50,  1.89s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5539/53576 [29:20<28:53:50,  2.17s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5540/53576 [29:23<32:00:00,  2.40s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5542/53576 [29:27<27:12:01,  2.04s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5543/53576 [29:28<26:00:04,  1.95s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5544/53576 [29:30<25:07:32,  1.88s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5545/53576 [29:31<23:15:33,  1.74s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5546/53576 [29:33<21:58:38,  1.65s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5547/53576 [29:34<21:02:09,  1.58s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5549/53576 [29:37<21:27:52,  1.61s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5550/53576 [29:39<22:06:39,  1.66s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5551/53576 [29:41<22:27:55,  1.68s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5554/53576 [29:44<17:11:10,  1.29s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5555/53576 [29:46<18:58:32,  1.42s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5556/53576 [29:48<20:30:02,  1.54s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5557/53576 [29:51<24:53:47,  1.87s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5558/53576 [29:53<28:25:50,  2.13s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5560/53576 [29:59<33:43:45,  2.53s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5561/53576 [30:01<30:42:53,  2.30s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5562/53576 [30:03<28:34:31,  2.14s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5574/53576 [30:16<12:41:30,  1.05it/s]Premature end of JPEG file
# Processing:  10%|####4                                      | 5575/53576 [30:18<15:55:44,  1.19s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5578/53576 [30:22<15:57:49,  1.20s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5579/53576 [30:23<16:48:31,  1.26s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5581/53576 [30:27<22:34:46,  1.69s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5584/53576 [30:32<19:07:58,  1.44s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5585/53576 [30:34<20:19:02,  1.52s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5586/53576 [30:35<21:10:25,  1.59s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5587/53576 [30:37<21:47:49,  1.64s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5588/53576 [30:39<22:11:03,  1.66s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5590/53576 [30:42<22:47:25,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5591/53576 [30:44<22:59:01,  1.72s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5594/53576 [30:48<17:07:13,  1.28s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5595/53576 [30:49<17:39:05,  1.32s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5598/53576 [30:53<16:21:10,  1.23s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5600/53576 [30:56<20:12:06,  1.52s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5601/53576 [30:59<25:13:06,  1.89s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5602/53576 [31:02<28:30:46,  2.14s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5603/53576 [31:04<27:43:34,  2.08s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5604/53576 [31:06<26:46:23,  2.01s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5605/53576 [31:07<25:57:57,  1.95s/it]Premature end of JPEG file
# Processing:  10%|####4                                      | 5606/53576 [31:10<27:31:37,  2.07s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5610/53576 [31:17<22:45:15,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5611/53576 [31:20<27:00:18,  2.03s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5612/53576 [31:23<30:04:31,  2.26s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5613/53576 [31:25<29:54:31,  2.24s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5614/53576 [31:27<29:45:11,  2.23s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5616/53576 [31:31<26:51:33,  2.02s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5617/53576 [31:33<27:48:56,  2.09s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5618/53576 [31:36<31:19:11,  2.35s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5619/53576 [31:39<32:55:35,  2.47s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5621/53576 [31:44<33:57:42,  2.55s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5624/53576 [31:49<22:49:42,  1.71s/it]Premature end of JPEG file
# Processing:  10%|####5                                      | 5625/53576 [31:51<26:18:00,  1.97s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5626/53576 [31:54<29:15:54,  2.20s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5627/53576 [31:56<27:48:52,  2.09s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5629/53576 [32:00<29:38:32,  2.23s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5630/53576 [32:03<32:31:23,  2.44s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5631/53576 [32:05<28:42:26,  2.16s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5632/53576 [32:06<25:55:10,  1.95s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5633/53576 [32:09<28:43:40,  2.16s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5634/53576 [32:11<31:07:12,  2.34s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5640/53576 [32:18<15:09:25,  1.14s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5641/53576 [32:20<19:19:37,  1.45s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5642/53576 [32:22<22:05:50,  1.66s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5644/53576 [32:25<20:44:18,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5645/53576 [32:27<21:40:27,  1.63s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5646/53576 [32:29<22:18:18,  1.68s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5647/53576 [32:31<22:44:24,  1.71s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5648/53576 [32:32<22:56:56,  1.72s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5649/53576 [32:34<21:54:48,  1.65s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5651/53576 [32:37<20:40:06,  1.55s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5652/53576 [32:38<20:20:50,  1.53s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5653/53576 [32:40<22:49:56,  1.72s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5658/53576 [32:50<21:24:58,  1.61s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5662/53576 [33:01<31:54:28,  2.40s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5663/53576 [33:02<28:05:30,  2.11s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5664/53576 [33:04<25:21:20,  1.91s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5665/53576 [33:05<23:31:04,  1.77s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5666/53576 [33:06<22:13:53,  1.67s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5667/53576 [33:08<21:20:05,  1.60s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5668/53576 [33:09<20:46:26,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5682/53576 [33:25<12:05:14,  1.10it/s]Premature end of JPEG file
# Processing:  11%|####5                                      | 5683/53576 [33:26<15:40:00,  1.18s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5684/53576 [33:28<18:10:36,  1.37s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5688/53576 [33:34<16:35:36,  1.25s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5689/53576 [33:35<17:30:30,  1.32s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5690/53576 [33:37<18:08:27,  1.36s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5691/53576 [33:38<19:58:36,  1.50s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5692/53576 [33:40<21:17:55,  1.60s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5693/53576 [33:43<23:34:52,  1.77s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5695/53576 [33:47<24:59:01,  1.88s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5696/53576 [33:48<24:43:21,  1.86s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5697/53576 [33:51<28:18:45,  2.13s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5704/53576 [34:00<14:45:15,  1.11s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5705/53576 [34:02<17:28:41,  1.31s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5706/53576 [34:03<19:30:53,  1.47s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5707/53576 [34:05<19:32:47,  1.47s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5714/53576 [34:12<12:40:11,  1.05it/s]Premature end of JPEG file
# Processing:  11%|####5                                      | 5718/53576 [34:18<18:58:30,  1.43s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5719/53576 [34:21<24:02:11,  1.81s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5722/53576 [34:26<20:01:43,  1.51s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5723/53576 [34:27<19:56:21,  1.50s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5726/53576 [34:30<15:43:03,  1.18s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5727/53576 [34:32<16:53:34,  1.27s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5728/53576 [34:33<17:41:13,  1.33s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5729/53576 [34:35<19:37:24,  1.48s/it]Premature end of JPEG file
# Processing:  11%|####5                                      | 5731/53576 [34:39<21:52:05,  1.65s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5732/53576 [34:40<22:29:39,  1.69s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5733/53576 [34:42<23:05:47,  1.74s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5738/53576 [34:48<16:10:19,  1.22s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5739/53576 [34:51<22:11:02,  1.67s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5740/53576 [34:54<26:47:53,  2.02s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5741/53576 [34:55<24:40:36,  1.86s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5745/53576 [35:00<18:54:27,  1.42s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5746/53576 [35:02<20:15:43,  1.53s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5747/53576 [35:03<19:57:06,  1.50s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5750/53576 [35:06<15:31:46,  1.17s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5751/53576 [35:08<17:54:47,  1.35s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5752/53576 [35:10<19:35:41,  1.48s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5753/53576 [35:12<20:41:47,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5755/53576 [35:15<20:45:08,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5758/53576 [35:19<19:36:56,  1.48s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5759/53576 [35:21<20:45:38,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5763/53576 [35:27<21:48:00,  1.64s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5764/53576 [35:30<26:00:10,  1.96s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5772/53576 [35:40<19:13:08,  1.45s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5773/53576 [35:42<20:26:40,  1.54s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5778/53576 [35:49<15:32:11,  1.17s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5779/53576 [35:51<19:13:32,  1.45s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5781/53576 [35:55<22:28:28,  1.69s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5782/53576 [35:56<22:50:00,  1.72s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5783/53576 [35:58<22:53:20,  1.72s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5788/53576 [36:04<17:58:31,  1.35s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5790/53576 [36:08<21:11:11,  1.60s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5791/53576 [36:10<22:06:25,  1.67s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5794/53576 [36:13<17:08:21,  1.29s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5796/53576 [36:19<27:11:02,  2.05s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5797/53576 [36:21<26:17:34,  1.98s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5798/53576 [36:23<25:44:31,  1.94s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5804/53576 [36:30<16:20:34,  1.23s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5805/53576 [36:33<21:56:13,  1.65s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5806/53576 [36:36<26:06:37,  1.97s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5807/53576 [36:38<29:24:12,  2.22s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5809/53576 [36:43<29:19:50,  2.21s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5810/53576 [36:45<27:32:26,  2.08s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5811/53576 [36:46<26:25:16,  1.99s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5815/53576 [36:54<25:58:01,  1.96s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5816/53576 [36:56<28:53:54,  2.18s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5818/53576 [37:01<28:28:31,  2.15s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5819/53576 [37:02<26:53:06,  2.03s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5821/53576 [37:07<28:41:57,  2.16s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5823/53576 [37:12<32:03:28,  2.42s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5824/53576 [37:15<32:36:45,  2.46s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5828/53576 [37:22<22:08:22,  1.67s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5829/53576 [37:23<22:16:20,  1.68s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5830/53576 [37:25<22:44:49,  1.72s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5831/53576 [37:28<26:40:34,  2.01s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5835/53576 [37:34<20:27:38,  1.54s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5836/53576 [37:35<19:51:56,  1.50s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5837/53576 [37:37<20:42:13,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5838/53576 [37:39<21:23:47,  1.61s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5839/53576 [37:40<21:54:03,  1.65s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5841/53576 [37:44<22:34:19,  1.70s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5842/53576 [37:46<23:03:56,  1.74s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5843/53576 [37:48<26:50:00,  2.02s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5844/53576 [37:51<29:09:06,  2.20s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5852/53576 [38:00<13:39:41,  1.03s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5853/53576 [38:01<15:17:08,  1.15s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5854/53576 [38:03<16:19:49,  1.23s/it]Premature end of JPEG file
# Processing:  11%|####6                                      | 5855/53576 [38:04<17:06:53,  1.29s/it]Premature end of JPEG file
# Processing:  11%|####7                                      | 5856/53576 [38:06<17:36:31,  1.33s/it]Premature end of JPEG file
# Processing:  11%|####7                                      | 5857/53576 [38:08<19:32:39,  1.47s/it]Premature end of JPEG file
# Processing:  11%|####7                                      | 5858/53576 [38:09<20:36:59,  1.56s/it]Premature end of JPEG file
# Processing:  11%|####7                                      | 5859/53576 [38:11<20:08:58,  1.52s/it]Premature end of JPEG file
# Processing:  11%|####7                                      | 5862/53576 [38:14<15:34:28,  1.18s/it]Premature end of JPEG file
# Processing:  11%|####7                                      | 5870/53576 [38:22<12:42:42,  1.04it/s]Premature end of JPEG file
# Processing:  11%|####7                                      | 5871/53576 [38:24<14:34:06,  1.10s/it]Premature end of JPEG file
# ...
# Processing:  95%|########################################7  | 50732/53576 [2:26:17<44:12,  1.07it/s]Premature end of JPEG file
# Processing:  95%|######################################8  | 50733/53576 [2:26:20<1:05:25,  1.38s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50734/53576 [2:26:22<1:17:55,  1.65s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50735/53576 [2:26:23<1:12:23,  1.53s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50738/53576 [2:26:26<52:45,  1.12s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50739/53576 [2:26:29<1:13:34,  1.56s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50742/53576 [2:26:34<1:13:21,  1.55s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50743/53576 [2:26:36<1:20:21,  1.70s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50744/53576 [2:26:38<1:26:50,  1.84s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50747/53576 [2:26:42<1:13:20,  1.56s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50748/53576 [2:26:44<1:16:10,  1.62s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50749/53576 [2:26:46<1:15:22,  1.60s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50750/53576 [2:26:47<1:12:55,  1.55s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50752/53576 [2:26:52<1:35:03,  2.02s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50753/53576 [2:26:54<1:40:58,  2.15s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50754/53576 [2:26:57<1:43:51,  2.21s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50755/53576 [2:26:58<1:35:07,  2.02s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50756/53576 [2:27:00<1:29:44,  1.91s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50757/53576 [2:27:01<1:20:02,  1.70s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50761/53576 [2:27:06<1:11:18,  1.52s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50762/53576 [2:27:09<1:23:46,  1.79s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50763/53576 [2:27:10<1:21:15,  1.73s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50769/53576 [2:27:17<52:11,  1.12s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50772/53576 [2:27:20<47:28,  1.02s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50773/53576 [2:27:21<54:39,  1.17s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50776/53576 [2:27:24<49:33,  1.06s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50777/53576 [2:27:26<57:29,  1.23s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50782/53576 [2:27:31<43:01,  1.08it/s]Premature end of JPEG file
# Processing:  95%|########################################7  | 50783/53576 [2:27:32<54:08,  1.16s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50786/53576 [2:27:38<1:20:20,  1.73s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50787/53576 [2:27:40<1:16:46,  1.65s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50789/53576 [2:27:43<1:23:29,  1.80s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50794/53576 [2:27:50<57:54,  1.25s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50795/53576 [2:27:53<1:12:44,  1.57s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50796/53576 [2:27:55<1:25:14,  1.84s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50797/53576 [2:27:58<1:34:33,  2.04s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50800/53576 [2:28:02<1:14:52,  1.62s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50802/53576 [2:28:05<1:12:17,  1.56s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50803/53576 [2:28:07<1:16:21,  1.65s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50806/53576 [2:28:12<1:15:42,  1.64s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50807/53576 [2:28:14<1:13:58,  1.60s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50809/53576 [2:28:17<1:20:14,  1.74s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50814/53576 [2:28:24<1:02:33,  1.36s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50818/53576 [2:28:29<52:03,  1.13s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50820/53576 [2:28:35<1:32:45,  2.02s/it]Premature end of JPEG file
# Processing:  95%|######################################8  | 50821/53576 [2:28:36<1:28:03,  1.92s/it]Premature end of JPEG file
# Processing:  95%|########################################7  | 50824/53576 [2:28:40<58:42,  1.28s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50833/53576 [2:28:51<1:00:11,  1.32s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50835/53576 [2:28:55<1:08:28,  1.50s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50836/53576 [2:28:56<1:08:56,  1.51s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50841/53576 [2:29:03<1:06:58,  1.47s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50842/53576 [2:29:05<1:18:09,  1.72s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50843/53576 [2:29:07<1:18:02,  1.71s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50844/53576 [2:29:09<1:17:02,  1.69s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50846/53576 [2:29:14<1:40:38,  2.21s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50847/53576 [2:29:16<1:34:14,  2.07s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50850/53576 [2:29:21<1:25:51,  1.89s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50851/53576 [2:29:24<1:33:34,  2.06s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50852/53576 [2:29:26<1:36:27,  2.12s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50854/53576 [2:29:28<1:15:16,  1.66s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50855/53576 [2:29:30<1:13:18,  1.62s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50860/53576 [2:29:34<42:21,  1.07it/s]Premature end of JPEG file
# Processing:  95%|########################################8  | 50861/53576 [2:29:37<58:52,  1.30s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50864/53576 [2:29:41<1:00:01,  1.33s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50866/53576 [2:29:44<1:07:16,  1.49s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50867/53576 [2:29:46<1:08:16,  1.51s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50870/53576 [2:29:49<50:37,  1.12s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50871/53576 [2:29:50<52:47,  1.17s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50872/53576 [2:29:51<53:30,  1.19s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50873/53576 [2:29:54<1:06:28,  1.48s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50874/53576 [2:29:56<1:18:08,  1.74s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50876/53576 [2:29:59<1:11:52,  1.60s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50877/53576 [2:30:00<1:07:32,  1.50s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50878/53576 [2:30:02<1:08:58,  1.53s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50879/53576 [2:30:03<1:10:31,  1.57s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50882/53576 [2:30:06<52:00,  1.16s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50883/53576 [2:30:08<57:51,  1.29s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50886/53576 [2:30:13<1:05:59,  1.47s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50890/53576 [2:30:17<46:28,  1.04s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50891/53576 [2:30:19<1:01:55,  1.38s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50898/53576 [2:30:28<45:52,  1.03s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50899/53576 [2:30:29<52:42,  1.18s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50903/53576 [2:30:36<1:03:58,  1.44s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50904/53576 [2:30:37<1:03:43,  1.43s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50905/53576 [2:30:39<1:04:26,  1.45s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50906/53576 [2:30:40<1:06:19,  1.49s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50907/53576 [2:30:42<1:15:30,  1.70s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50910/53576 [2:30:46<59:55,  1.35s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50911/53576 [2:30:49<1:10:30,  1.59s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50912/53576 [2:30:51<1:19:39,  1.79s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50932/53576 [2:31:15<42:12,  1.04it/s]Premature end of JPEG file
# Processing:  95%|########################################8  | 50933/53576 [2:31:17<59:31,  1.35s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50934/53576 [2:31:19<1:10:16,  1.60s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50935/53576 [2:31:22<1:18:17,  1.78s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50937/53576 [2:31:26<1:27:32,  1.99s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50938/53576 [2:31:28<1:29:35,  2.04s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50940/53576 [2:31:31<1:16:09,  1.73s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50941/53576 [2:31:34<1:26:36,  1.97s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50943/53576 [2:31:38<1:33:53,  2.14s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50945/53576 [2:31:42<1:26:41,  1.98s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50950/53576 [2:31:47<44:28,  1.02s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50951/53576 [2:31:48<49:57,  1.14s/it]Premature end of JPEG file
# Processing:  95%|########################################8  | 50952/53576 [2:31:50<57:10,  1.31s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50954/53576 [2:31:53<1:04:10,  1.47s/it]Premature end of JPEG file
# Processing:  95%|######################################9  | 50955/53576 [2:31:55<1:17:16,  1.77s/it]Premature end of JPEG file
# Processing:  95%|########################################9  | 50962/53576 [2:32:03<45:15,  1.04s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50964/53576 [2:32:07<1:11:19,  1.64s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50965/53576 [2:32:10<1:24:42,  1.95s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50972/53576 [2:32:22<1:10:25,  1.62s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50973/53576 [2:32:23<1:07:19,  1.55s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50975/53576 [2:32:27<1:13:14,  1.69s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50976/53576 [2:32:29<1:19:46,  1.84s/it]Premature end of JPEG file
# Processing:  95%|#######################################  | 50977/53576 [2:32:30<1:12:47,  1.68s/it]Premature end of JPEG file
# Processing:  95%|########################################9  | 50988/53576 [2:32:41<29:41,  1.45it/s]Premature end of JPEG file
# Processing:  95%|########################################9  | 50989/53576 [2:32:43<40:18,  1.07it/s]Premature end of JPEG file
# Processing:  95%|########################################9  | 50994/53576 [2:32:48<39:35,  1.09it/s]Premature end of JPEG file
# Processing:  95%|########################################9  | 51000/53576 [2:32:56<52:25,  1.22s/it]Premature end of JPEG file
# Processing:  95%|########################################9  | 51001/53576 [2:32:58<58:22,  1.36s/it]Premature end of JPEG file
# Processing:  95%|########################################9  | 51008/53576 [2:33:05<41:00,  1.04it/s]Premature end of JPEG file
# Processing:  99%|##########################################5| 52965/53576 [3:19:52<09:24,  1.08it/s]Premature end of JPEG file
# Processing:  99%|##########################################5| 52967/53576 [3:19:54<11:43,  1.16s/it]Premature end of JPEG file
# Processing:  99%|##########################################5| 52968/53576 [3:19:56<13:29,  1.33s/it]Premature end of JPEG file
# Processing:  99%|##########################################5| 52969/53576 [3:19:58<14:34,  1.44s/it]Premature end of JPEG file
# Processing: 100%|###########################################| 53576/53576 [3:32:18<00:00,  4.21it/s]
# Numero di immagini non lette o con errori di processing: 45134
# Numero di immagini con bounding box del fondo nullo o non valido: 0
# Processo di suddivisione e preprocessing completato!
